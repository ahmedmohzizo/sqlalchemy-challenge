# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite", echo=False)

# %%
engine
# Out:
# Engine(sqlite:///Resources/hawaii.sqlite)

# %%
# reflect an existing database into a new model

Base = automap_base()

# %%
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
Station
# Out:
# sqlalchemy.ext.automap.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
session

# %%
session.query(Measurement.station,Measurement.date,Measurement.prcp,Measurement.tobs).first()
# Out:
# ('USC00519397', '2010-01-01', 0.08, 65.0)

# %%
session.query(Station.id,Station.station,Station.name,Station.latitude,Station.longitude,Station.elevation).first()
# Out:
# (1, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.
most_date = session.query(func.max(Measurement.date)).first()
most_date
# Out:
# ('2017-08-23')

# %%
# Calculate the date one year from the last date in data set.
year = dt.date(2017, 8, 23) - dt.timedelta(days = 365)
year
# Out:
# datetime.date(2016, 8, 23)

# %%
# Perform a query to retrieve the date and precipitation scores
retrieve = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date>=year).all()
retrieve
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0),
#  ('2016-09-03', 0.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-05', None),
#  ('2016-09-06', None),
#  ('2016-09-07', 0.05),
#  ('2016-09-08', 0.0),
#  ('2016-09-09', 0.03),
#  ('2016-09-10', 0.0),
#  ('2016-09-11', 0.05),
#  ('2016-09-12', 0.0),
#  ('2016-09-13', 0.02),
#  ('2016-09-14', 1.32),
#  ('2016-09-15', 0.42),
#  ('2016-09-16', 0.06),
#  ('2016-09-17', 0.05),
#  ('2016-09-18', 0.0),
#  ('2016-09-19', 0.0),
#  ('2016-09-20', 0.0),
#  ('2016-09-21', 0.0),
#  ('2016-09-22', 0.02),
#  ('2016-09-23', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-26', 0.06),
#  ('2016-09-27', 0.02),
#  ('2016-09-28', 0.0),
#  ('2016-09-29', 0.0),
#  ('2016-09-30', 0.0),
#  ('2016-10-01', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
rain_df = pd.DataFrame(retrieve, columns=['date', 'precipitation(in)'])
rain_df
# Out:
#             date  precipitation(in)
# 0     2016-08-23               0.00
# 1     2016-08-24               0.08
# 2     2016-08-25               0.08
# 3     2016-08-26               0.00
# 4     2016-08-27               0.00
# ...          ...                ...
# 2225  2017-08-19               0.09
# 2226  2017-08-20                NaN
# 2227  2017-08-21               0.56
# 2228  2017-08-22               0.50
# 2229  2017-08-23               0.45
#
# [2230 rows x 2 columns]

# %%
rain_df = rain_df.sort_values('date')
rain_df
# Out:
#             date  precipitation(in)
# 0     2016-08-23               0.00
# 1009  2016-08-23                NaN
# 1529  2016-08-23               1.79
# 704   2016-08-23               0.05
# 361   2016-08-23               0.15
# ...          ...                ...
# 1527  2017-08-22               0.00
# 1008  2017-08-23               0.00
# 360   2017-08-23               0.00
# 1528  2017-08-23               0.08
# 2229  2017-08-23               0.45
#
# [2230 rows x 2 columns]

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
rain_df.plot(x='date', y='precipitation(in)',rot=90)
plt.title(" the last twelve months", size=15)
plt.ylabel("Inches")
plt.xlabel("Year")
plt.savefig('prcp_for_twelve_months.png')

# %%
rain_df.describe()
# Out:
#        precipitation(in)
# count        2021.000000
# mean            0.177279
# std             0.461190
# min             0.000000
# 25%             0.000000
# 50%             0.020000
# 75%             0.130000
# max             6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
station_count = session.query(func.count(Station.station)).all()
station_count
# Out:
# [(9)]

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.
active_stations = session.query(Measurement.station, func.count(Measurement.station)).\
    group_by(Measurement.station).\
    order_by(Measurement.station).\
    all()
active_stations
# Out:
# [('USC00511918', 1979),
#  ('USC00513117', 2709),
#  ('USC00514830', 2202),
#  ('USC00516128', 2612),
#  ('USC00517948', 1372),
#  ('USC00518838', 511),
#  ('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00519523', 2669)]

# %%
active_stations
active_stations[0][0]
# Out:
# 'USC00511918'

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
temp_data = session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
                        filter(Measurement.station==active_stations[0][0]).all()
temp_data
# Out:
# [(53.0, 87.0, 71.61596766043456)]

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
recent_temp = session.query(Measurement.tobs).filter(Measurement.date>=year).\
                filter(Measurement.station=='USC00519281').all()
#SELECT tobs FROM Measurement WHERE date>=earliest_date AND station='USC'
temp_df = pd.DataFrame(recent_temp)
temp_df.plot.hist(bins=12)
plt.xlabel('Temperature')
plt.ylabel('Frequency ')
plt.title("Temperatures")
plt.legend(title="Temperature Observed")
plt.show()

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
